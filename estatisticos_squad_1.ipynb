# %%
#permite que os gráficos gerados sejam mostrados na mesma janela
# %matplotlib inline 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets, linear_model 
from sklearn.model_selection import train_test_split 
#import plotly.graph_objs as go
#define o estilo dos gráficos , "ggplot" é um estilo popular em R
plt.style.use('ggplot')

# %%
#@title Default title text
#Realiza a leitura da base (csv) e carrega na mémoria
dataBase = pd.read_csv('estaticos_market.csv')

# %% [markdown]
# <h1>Análise dos dados<h1>

# %%
dataBase.head()
# Out:
#    Unnamed: 0                                                 id  fl_matriz  \
# 0           0  a6984c3ae395090e3bee8ad63c3758b110de096d5d8195...       True
# 1           1  6178f41ade1365e44bc2c46654c2c8c0eaae27dcb476c4...       True
# 2           2  4a7e5069a397f12fdd7fd57111d6dc5d3ba558958efc02...       True
# 3           3  3348900fe63216a439d2e5238c79ddd46ede454df7b9d8...       True
# 4           4  1f9bcabc9d3173c1fe769899e4fac14b053037b953a1e4...       True
#
#             de_natureza_juridica sg_uf natureza_juridica_macro  \
# 0  SOCIEDADE EMPRESARIA LIMITADA    RN  ENTIDADES EMPRESARIAIS
# 1          EMPRESARIO INDIVIDUAL    PI                  OUTROS
# 2          EMPRESARIO INDIVIDUAL    AM                  OUTROS
# 3          EMPRESARIO INDIVIDUAL    AM                  OUTROS
# 4          EMPRESARIO INDIVIDUAL    RN                  OUTROS
#
#                                           de_ramo             setor  \
# ...

# %%
#verificando o tamanho da Base
dataBase.shape
# Out:
# (462298, 182)

# %%
#Verificando os nomes das colunas
dataBase.columns
# Out:
# Index(['Unnamed: 0', 'id', 'fl_matriz', 'de_natureza_juridica', 'sg_uf',
#        'natureza_juridica_macro', 'de_ramo', 'setor', 'idade_empresa_anos',
#        'idade_emp_cat',
#        ...
#        'media_meses_servicos', 'max_meses_servicos', 'min_meses_servicos',
#        'qt_funcionarios', 'qt_funcionarios_12meses', 'qt_funcionarios_24meses',
#        'tx_crescimento_12meses', 'tx_crescimento_24meses', 'tx_rotatividade',
#        'qt_filiais'],
#       dtype='object', length=182)

# %%
#verificando a tipagem dos dados
dataBase.dtypes
# Out:
# Unnamed: 0                   int64
# id                          object
# fl_matriz                     bool
# de_natureza_juridica        object
# sg_uf                       object
#                             ...
# qt_funcionarios_24meses    float64
# tx_crescimento_12meses     float64
# tx_crescimento_24meses     float64
# tx_rotatividade            float64
# qt_filiais                   int64
# Length: 182, dtype: object

# %%
#Verificando valores nulos
total = dataBase.isnull().sum().sort_values(ascending=False)
percent = (dataBase.isnull().sum()/dataBase.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#                                     Total   Percent
# qt_alteracao_socio_180d            462298  1.000000
# grau_instrucao_macro_desconhecido  462298  1.000000
# qt_alteracao_socio_90d             462298  1.000000
# qt_alteracao_socio_365d            462298  1.000000
# qt_alteracao_socio_total           462298  1.000000
# coligada_mais_nova_baixada         462162  0.999706
# coligada_mais_antiga_baixada       462162  0.999706
# idade_media_coligadas_baixadas     462162  0.999706
# vl_total_veiculos_antt             462122  0.999619
# vl_total_tancagem                  462018  0.999394
# vl_total_veiculos_antt_grupo       461962  0.999273
# vl_total_tancagem_grupo            460538  0.996193
# grau_instrucao_macro_analfabeto    460414  0.995925
# idade_ate_18                       459392  0.993714
# qt_socios_st_suspensa              459047  0.992968
# vl_potenc_cons_oleo_gas            458615  0.992033
# qt_socios_pj_suspensos             457754  0.990171
# ...

# %%
#Verificando os valores nulos e mostrando a quantidade por coluna
for i in dataBase.columns:
    nulls_value = dataBase[i].isna().sum()
    message = "Column {} has {} nulls".format(i, nulls_value)
    print(message)
# Out:
# Column Unnamed: 0 has 0 nulls
# Column id has 0 nulls
# Column fl_matriz has 0 nulls
# Column de_natureza_juridica has 0 nulls
# Column sg_uf has 0 nulls
# Column natureza_juridica_macro has 0 nulls
# Column de_ramo has 0 nulls
# Column setor has 1927 nulls
# Column idade_empresa_anos has 0 nulls
# Column idade_emp_cat has 0 nulls
# Column fl_me has 0 nulls
# Column fl_sa has 0 nulls
# Column fl_epp has 0 nulls
# Column fl_mei has 0 nulls
# Column fl_ltda has 0 nulls
# Column dt_situacao has 6 nulls
# Column fl_st_especial has 0 nulls
# Column fl_email has 0 nulls
# Column fl_telefone has 0 nulls
# Column fl_rm has 0 nulls
# Column nm_divisao has 1927 nulls
# Column nm_segmento has 1927 nulls
# Column fl_spa has 1927 nulls
# Column fl_antt has 1927 nulls
# Column fl_veiculo has 1927 nulls
# Column vl_total_tancagem has 462018 nulls
# Column vl_total_veiculos_antt has 462122 nulls
# Column vl_total_veiculos_leves has 431614 nulls
# Column vl_total_veiculos_pesados has 431614 nulls
# ...

# %%
import pandas_profiling
profile = dataBase.profile_report(title="Estatisticos Dataset")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-4446dab80495> in <module>
# ----> 1 import pandas_profiling
#       2 profile = dataBase.profile_report(title="Estatisticos Dataset")
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %% [markdown]
# <h1>Cluster</h1>

# %%
x = dataBase.iloc[:, [3, 4]].values

# let's check the shape of x
print(x.shape)
# Out:
# (462298, 2)

# %%
from sklearn.cluster import KMeans

wcss = []
for i in range(1, 11):
    km = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    km.fit(x)
    wcss.append(km.inertia_)
    
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method', fontsize = 20)
plt.xlabel('No. of Clusters')
plt.ylabel('wcss')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-3cbb5aa7230f> in <module>
#       4 for i in range(1, 11):
#       5     km = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
# ----> 6     km.fit(x)
#       7     wcss.append(km.inertia_)
#       8
#
# /anaconda3/lib/python3.6/site-packages/sklearn/cluster/k_means_.py in fit(self, X, y, sample_weight)
#     967                 tol=self.tol, random_state=random_state, copy_x=self.copy_x,
#     968                 n_jobs=self.n_jobs, algorithm=self.algorithm,
# --> 969                 return_n_iter=True)
#     970         return self
#     971
#
# /anaconda3/lib/python3.6/site-packages/sklearn/cluster/k_means_.py in k_means(X, n_clusters, sample_weight, init, precompute_distances, n_init, max_iter, verbose, tol, random_state, copy_x, n_jobs, algorithm, return_n_iter)
# ...
